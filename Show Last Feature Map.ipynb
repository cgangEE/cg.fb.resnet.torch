-- %%
require 'torch'
require 'paths'
require 'cudnn'
require 'cunn'
require 'image'
require 'socket'

function sumUp(o)
    local x = o[{{},1,{},{}}]
    local y = torch.zeros( x:size()):cuda()

    for i = 1,(o:size(2)) do
        x = o[{{},i,{},{}}] 
        y = y + x
    end
    y = nn.utils.recursiveType(y, 'torch.FloatTensor')
    return y
end

model = torch.load('checkpointFlickr200_1/model_38.t7'):cuda()


model:evaluate()
l = model:get(1)


meanstd = {
    mean = { 0.485, 0.456, 0.406 },
    std = { 0.229, 0.224, 0.225 },
}

t = require './datasets/transforms'

transform = t.Compose{
    t.Scale(256),
    t.ColorNormalize(meanstd),
    t.CenterCrop(224),
}


img = image.load('./2.jpg', 3, 'float')
img = transform(img)

itorch.image(img)


output = model:forward(img:cuda())
o = model:get(8).output

print(output)
y = sumUp(o)
y = image.scale(y, img:size(3), img:size(2), 'bilinear')


itorch.image(y)
-- Out:
-- Console does not support images
-- -4.3304  4.5995
-- [torch.CudaTensor of size 1x2]
-- Console does not support images
